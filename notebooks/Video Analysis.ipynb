# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install moviepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install imageio-ffmpeg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import moviepy.editor as mp

# %%
clip=mp.VideoFileClip(r"/content/drive/MyDrive/PROJECTS/video analysis/IELTS Speaking Interview | Band 8 | with Feedback (2023 February).mp4")

# %%
clip.audio.write_audiofile(r"audio.wav")
# Out:
# chunk:   3%|▎         | 408/12483 [00:00<00:03, 4019.34it/s, now=None]
# MoviePy - Writing audio in audio.wav
# MoviePy - Done.

# %%
# !pip install pydub

# %%
# !pip install speechrecognition

# %%
import speech_recognition as sr 
import os 
from pydub import AudioSegment
from pydub.silence import split_on_silence
r = sr.Recognizer()
def get_large_audio_transcription(path):
    sound = AudioSegment.from_wav(path)  
    chunks = split_on_silence(sound,
        min_silence_len = 500,
        silence_thresh = sound.dBFS-14,
        keep_silence=500,
    )
    folder_name = "audio-chunks"
    if not os.path.isdir(folder_name):
        os.mkdir(folder_name)
    whole_text = ""
    for i, audio_chunk in enumerate(chunks, start=1):
        chunk_filename = os.path.join(folder_name, f"chunk{i}.wav")
        audio_chunk.export(chunk_filename, format="wav")
        with sr.AudioFile(chunk_filename) as source:
            audio_listened = r.record(source)
            try:
                text = r.recognize_google(audio_listened)
            except sr.UnknownValueError as e:
                print("Error:", str(e))
            else:
                text = f"{text.capitalize()}. "
                print(chunk_filename, ":", text)
                whole_text += text
    return whole_text
path = "audio.wav"
s=get_large_audio_transcription(path)
print("\nFull text:",s)
# Out:
# Error:
# audio-chunks/chunk2.wav : Ao.com ios test preparation videos i would not think she four important strategies.
# audio-chunks/chunk3.wav : Start all speak in interview with the time now.
# audio-chunks/chunk4.wav : I will also include example.
# audio-chunks/chunk5.wav : Phone attend a square band to show you just what to do.
# audio-chunks/chunk6.wav : Again we have coronavirus skillshare.
# audio-chunks/chunk7.wav : Overall class plus one from hundreds of different skills of heart by professionals.
# audio-chunks/chunk8.wav : Whether you're looking to improve your writing work communication in english.
# audio-chunks/chunk9.wav : Future husband wife quotes.
# audio-chunks/chunk10.wav : How to succeed in learning a new language.
# audio-chunks/chunk11.wav : I have been studying across ko product theory with purpose.
# audio-chunks/chunk12.wav : Sugar i can bring in more videos and content.
# audio-chunks/chunk13.wav : Temple funny oil exam.
# ...

# %%
s
# Out:
# "Ao.com ios test preparation videos i would not think she four important strategies. Start all speak in interview with the time now. I will also include example. Phone attend a square band to show you just what to do. Again we have coronavirus skillshare. Overall class plus one from hundreds of different skills of heart by professionals. Whether you're looking to improve your writing work communication in english. Future husband wife quotes. How to succeed in learning a new language. I have been studying across ko product theory with purpose. Sugar i can bring in more videos and content. Temple funny oil exam. Future has given. Especially. In the video description the first 1000 people to sign up via my link. What is this question of premium for one month. For free now. Angela. The first priority to get a perfect and 9 in one is bill. Conference. It's ok to be nervous going in 3 exam. 2 march d conference sc registered speaking. Conference. Initial factors for speaking interview mont
# ...

# %%
text="""Ao.com ios test preparation videos i would not think she four important strategies. Start all speak in interview with the time now. I will also include example. Phone attend a square band to show you just what to do. Again we have coronavirus skillshare. Overall class plus one from hundreds of different skills of heart by professionals. Whether you're looking to improve your writing work communication in english. Future husband wife quotes. How to succeed in learning a new language. I have been studying cosco product theory with purpose. Sugar i can bring in more videos and content. Temple funny oil exam. Future has given. Especially. In the video description the first 1000 people to sign up via my link. What is this question of premium for one month. For free now. Angela. The first priority to get a perfect and 9 in one is bill. Conference. It's ok to be nervous going in 3 exam. 2 march d conference sc registered speaking. Conference. Initial factors for speaking interview months before your exam. Ok so arrived today exam centre in our before the start time are you speaking interview. Popular speaking scripts with you. Find candidates waiting for their exam and ask them to practice with you. When you meet with exam. Imaginative examiner is like your grandfather grandmother visualise this. Person who loves you cares for you in this maujudgi. Speak loud and clearly so grandpa and grandma can understand. Use the icebreaker questions to build your confidence. One needs and asked you for your password. For your name. Whether you work or study. Remember to speak in full sentences loud and clear. Best really do jo conference going into the part 1 questions. Make sure to practice this before your exam. Listen to these bands 908 use these icebreaker questions indian clear for sentence answers. Tomorrow is your phone. Ok madina. Mah ssc result fixation. Thank you. Hari ji dickinson's exam. I came here by ka my friends pick me up at my place and dropped me here are 30 minutes to for this casual interview. How are you go back home. Is time. My friend agreed to take me home i just need to send a text message. Sar ji number 2. One is going to be all about you. Ask questions on a general topic. White spots in heart. Which question would be asking about your life in your experiences. Chitra cinema. Mixture the answer for one question. Use the pronouns i me my. Do you know use the world. You can people you are not talking about examiner you not talking about people in general. Cheap person first person. Fb exam app. What is your favourite sport. Answer my favourite sport is football because i get the hang out with my friends and get a good workout. Ipl cup game last week and i had whatsapp fund. This is what i need to do to get that now. Watch these candidates covid-19 do just that. Satta live. What do you do for fun. Diffuse activity centre for enjoyment. All i can go out with friends and family. Going to the movies are going for swim. Yesterday islam for an hour or so. And i had a good time. How often do you use english. English and daily basis. But i am talking to my international fans over kali. Social media for purchase and stores. Using english. Quora jee number 3. One use the question the examiner is asking you. In your answers to give really quickly responses. Mixture to paraphrase what the examiner is asking you. For instance if the examiners asking you. What is your favourite sport. You can enter. The sport that i love the most. Is. Football. Because i get hanging out with friends and get a good workout. I just played a few days last week and had lots of fun. Notice how i started by hair praising the question in using the four question in my answer. Once again this was truly bump up your fluency score. Which should practice this. What have these candidates do just that the score a band 9. Could you like spending time with. Funny time with my family friends. I have friends that i grow up wiz and we are quite close. Expected this cup of ours is my good friend leela. Just before coming to dg you have a good chat on whatsapp. Saamy 2 song lakshmi practice. How learning languages changed. Parivahan. Because of considerable improvement in technology. Patient. Study for native speakers of language. Boss naukari and shruti internet. 32 bore of english 20 l l and using apps. Priority number 4. 1. 1 year exam asked you question. Mixture tukur the answer and explanation and a smooth flowing example. I have realised that i've been doing just now for the past two strategies. 1 exam ask me. What is your favourite sport. I start with t answer. The sport i love the most is football. I think you with an explanation. Vikas i get the hang out with my friends. And i get your workout. Then i finished with us news example. Popular games just last week and i had tons of fun. Do ink will for instance of example. Exam scare the evil speak to month and goa thought. Just give the example. Watch how these students. Usko aur band 9 do you just this. Free you spend your free time. I spent my fan by myself or with my friends. 4 days ago i have switched to my friends for most of the day catching up and doing shopping. Languages why do people learn languages. The primary reason for people starting languages is to communicate with others. Vatan desh hippo require languages for work. Studying and living in foreign countries. I think my higher education duty. Poor many more video lessons like this one. Enquiry over 180 videos of poland track the course and origin of practice exams. Enjoy 9 premium package. We have talked it so one time payment for lifetime access and it will improve your bags for boys. Tula the next time you say you ask exam. Subscribe to our channel click here watch another video click here. Quikr olx hero to join our premium package and get access to all over videos. Practice exams and fully interactive course."""

# %%
# !pip install -U spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      |████████████████████████████████| 13.6 MB 12.0 MB/s eta 0:00:01
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %%
stopwords=list(STOP_WORDS)

# %%
stopwords
# Out:
# ['only',
#  'it',
#  'none',
#  'else',
#  'move',
#  'forty',
#  'into',
#  'beside',
#  'whoever',
#  'yet',
#  'few',
#  'both',
#  'although',
#  'some',
#  'neither',
#  'somewhere',
#  'please',
#  'eight',
#  'very',
#  'do',
#  'they',
#  'where',
#  'to',
#  'myself',
#  'them',
#  'not',
#  'herself',
#  'among',
#  'whither',
#  'should',
#  'our',
#  'themselves',
#  "'re",
#  'any',
#  'up',
#  '‘m',
#  'its',
#  'onto',
#  'say',
#  'whether',
#  'anyone',
#  'off',
#  'anywhere',
#  'except',
#  'seeming',
#  'get',
#  'due',
#  'nowhere',
#  'before',
#  'is',
#  'rather',
#  'n’t',
#  'nobody',
#  'often',
#  'than',
#  'mine',
#  'indeed',
#  'sometime',
#  'somehow',
#  'nothing',
#  'others',
#  'whose',
#  'her',
#  'which',
#  'in',
#  'against',
#  'name',
#  "'d",
#  'every',
#  'most',
#  'made',
#  'always',
#  'seem',
#  'these',
#  'using',
#  'this',
#  'latterly',
#  'all',
#  'down',
#  'did',
#  'hereafter',
#  'behind',
#  "'ve",
#  'put',
# ...

# %%
nlp=spacy.load('en_core_web_sm')

# %%
doc=nlp(text)

# %%
doc
# Out:
# Ao.com ios test preparation videos i would not think she four important strategies. Start all speak in interview with the time now. I will also include example. Phone attend a square band to show you just what to do. Again we have coronavirus skillshare. Overall class plus one from hundreds of different skills of heart by professionals. Whether you're looking to improve your writing work communication in english. Future husband wife quotes. How to succeed in learning a new language. I have been studying cosco product theory with purpose. Sugar i can bring in more videos and content. Temple funny oil exam. Future has given. Especially. In the video description the first 1000 people to sign up via my link. What is this question of premium for one month. For free now. Angela. The first priority to get a perfect and 9 in one is bill. Conference. It's ok to be nervous going in 3 exam. 2 march d conference sc registered speaking. Conference. Initial factors for speaking interview months be
# ...

# %%
tokens = [token.text for token in doc]
print(tokens)
# Out:
# ['Ao.com', 'ios', 'test', 'preparation', 'videos', 'i', 'would', 'not', 'think', 'she', 'four', 'important', 'strategies', '.', 'Start', 'all', 'speak', 'in', 'interview', 'with', 'the', 'time', 'now', '.', 'I', 'will', 'also', 'include', 'example', '.', 'Phone', 'attend', 'a', 'square', 'band', 'to', 'show', 'you', 'just', 'what', 'to', 'do', '.', 'Again', 'we', 'have', 'coronavirus', 'skillshare', '.', 'Overall', 'class', 'plus', 'one', 'from', 'hundreds', 'of', 'different', 'skills', 'of', 'heart', 'by', 'professionals', '.', 'Whether', 'you', "'re", 'looking', 'to', 'improve', 'your', 'writing', 'work', 'communication', 'in', 'english', '.', 'Future', 'husband', 'wife', 'quotes', '.', 'How', 'to', 'succeed', 'in', 'learning', 'a', 'new', 'language', '.', 'I', 'have', 'been', 'studying', 'cosco', 'product', 'theory', 'with', 'purpose', '.', 'Sugar', 'i', 'can', 'bring', 'in', 'more', 'videos', 'and', 'content', '.', 'Temple', 'funny', 'oil', 'exam', '.', 'Future', 'has', 'given', 
# ...

# %%
punctuation=punctuation+'\n'

# %%
word_frequencies={}
for word in doc:
    if word.text.lower() not in stopwords:
        if word.text.lower() not in punctuation:
            if word.text not in word_frequencies.keys():
                word_frequencies[word.text]=1
            else:
                word_frequencies[word.text]+=1

# %%
print(word_frequencies)
# Out:
# {'Ao.com': 1, 'ios': 1, 'test': 1, 'preparation': 1, 'videos': 4, 'think': 3, 'important': 1, 'strategies': 2, 'Start': 1, 'speak': 3, 'interview': 4, 'time': 9, 'include': 1, 'example': 5, 'Phone': 1, 'attend': 1, 'square': 1, 'band': 3, 'coronavirus': 1, 'skillshare': 1, 'Overall': 1, 'class': 1, 'plus': 1, 'hundreds': 1, 'different': 1, 'skills': 1, 'heart': 2, 'professionals': 1, 'looking': 1, 'improve': 2, 'writing': 1, 'work': 3, 'communication': 1, 'english': 4, 'Future': 2, 'husband': 1, 'wife': 1, 'quotes': 1, 'succeed': 1, 'learning': 2, 'new': 1, 'language': 2, 'studying': 1, 'cosco': 1, 'product': 1, 'theory': 1, 'purpose': 1, 'Sugar': 1, 'bring': 1, 'content': 1, 'Temple': 1, 'funny': 1, 'oil': 1, 'exam': 12, 'given': 1, 'Especially': 1, 'video': 3, 'description': 1, '1000': 1, 'people': 5, 'sign': 1, 'link': 1, 'question': 7, 'premium': 3, 'month': 2, 'free': 2, 'Angela': 1, 'priority': 1, 'perfect': 1, '9': 4, 'bill': 1, 'Conference': 2, 'ok': 1, 'nervous': 1, 'going':
# ...

# %%
max_frequency= max(word_frequencies.values())

# %%
max_frequency
# Out:
# 12

# %%
for word in word_frequencies.keys():
    word_frequencies[word]=word_frequencies[word]/max_frequency

# %%
print(word_frequencies)
# Out:
# {'Ao.com': 0.08333333333333333, 'ios': 0.08333333333333333, 'test': 0.08333333333333333, 'preparation': 0.08333333333333333, 'videos': 0.3333333333333333, 'think': 0.25, 'important': 0.08333333333333333, 'strategies': 0.16666666666666666, 'Start': 0.08333333333333333, 'speak': 0.25, 'interview': 0.3333333333333333, 'time': 0.75, 'include': 0.08333333333333333, 'example': 0.4166666666666667, 'Phone': 0.08333333333333333, 'attend': 0.08333333333333333, 'square': 0.08333333333333333, 'band': 0.25, 'coronavirus': 0.08333333333333333, 'skillshare': 0.08333333333333333, 'Overall': 0.08333333333333333, 'class': 0.08333333333333333, 'plus': 0.08333333333333333, 'hundreds': 0.08333333333333333, 'different': 0.08333333333333333, 'skills': 0.08333333333333333, 'heart': 0.16666666666666666, 'professionals': 0.08333333333333333, 'looking': 0.08333333333333333, 'improve': 0.16666666666666666, 'writing': 0.08333333333333333, 'work': 0.25, 'communication': 0.08333333333333333, 'english': 0.333333333
# ...

# %%
sentence_tokens=[sent for sent in doc.sents]
print(sentence_tokens)
# Out:
# [Ao.com ios test preparation videos i would not think she four important strategies., Start all speak in interview with the time now., I will also include example., Phone attend a square band to show you just what to do., Again we have coronavirus skillshare., Overall class plus one from hundreds of different skills of heart by professionals., Whether you're looking to improve your writing work communication in english., Future husband wife quotes., How to succeed in learning a new language., I have been studying cosco product theory with purpose., Sugar i can bring in more videos and content., Temple funny oil exam., Future has given., Especially., In the video description the first 1000 people to sign up via my link., What is this question of premium for one month., For free now., Angela., The first priority to get a perfect and 9 in one is bill., Conference., It's ok to be nervous going in 3 exam., 2 march d conference sc registered speaking., Conference., Initial factors for spea
# ...

# %%
sentence_scores={}
for sent in sentence_tokens:
    for word in sent:
        if word.text.lower() in word_frequencies.keys():
            if sent not in sentence_scores.keys():
                sentence_scores[sent]=word_frequencies[word.text.lower()]
            else:
                sentence_scores[sent]+=word_frequencies[word.text.lower()]

# %%
 sentence_scores
# Out:
# {Ao.com ios test preparation videos i would not think she four important strategies.: 1.0833333333333333,
#  Start all speak in interview with the time now.: 1.5,
#  I will also include example.: 0.5,
#  Phone attend a square band to show you just what to do.: 0.5,
#  Again we have coronavirus skillshare.: 0.16666666666666666,
#  Overall class plus one from hundreds of different skills of heart by professionals.: 0.6666666666666666,
#  Whether you're looking to improve your writing work communication in english.: 1.0,
#  Future husband wife quotes.: 0.25,
#  How to succeed in learning a new language.: 0.5,
#  I have been studying cosco product theory with purpose.: 0.41666666666666663,
#  Sugar i can bring in more videos and content.: 0.49999999999999994,
#  Temple funny oil exam.: 1.1666666666666667,
#  Future has given.: 0.08333333333333333,
#  In the video description the first 1000 people to sign up via my link.: 1.0,
#  What is this question of premium for one month.: 1.0,
# ...

# %%
from heapq import nlargest

# %%
select_length=int(len(sentence_tokens)*0.3)

# %%
summary=nlargest(select_length,sentence_scores,key=sentence_scores.get)

# %%
summary
# Out:
# [Ok so arrived today exam centre in our before the start time are you speaking interview.,
#  Answer my favourite sport is football because i get the hang out with my friends and get a good workout.,
#  1. 1 year exam asked you question.,
#  Find candidates waiting for their exam and ask them to practice with you.,
#  Tula the next time you say you ask exam.,
#  Initial factors for speaking interview months before your exam.,
#  You can people you are not talking about examiner you not talking about people in general.,
#  Notice how i started by hair praising the question in using the four question in my answer.,
#  Funny time with my family friends.,
#  Exam scare the evil speak to month and goa thought.,
#  I came here by ka my friends pick me up at my place and dropped me here are 30 minutes to for this casual interview.,
#  It's ok to be nervous going in 3 exam.,
#  One use the question the examiner is asking you.,
#  1 exam ask me.,
# ...

# %%
final_summary=[word.text for word in summary]

# %%
final_summary[:]
# Out:
# ['Ok so arrived today exam centre in our before the start time are you speaking interview.',
#  'Answer my favourite sport is football because i get the hang out with my friends and get a good workout.',
#  '1. 1 year exam asked you question.',
#  'Find candidates waiting for their exam and ask them to practice with you.',
#  'Tula the next time you say you ask exam.',
#  'Initial factors for speaking interview months before your exam.',
#  'You can people you are not talking about examiner you not talking about people in general.',
#  'Notice how i started by hair praising the question in using the four question in my answer.',
#  'Funny time with my family friends.',
#  'Exam scare the evil speak to month and goa thought.',
#  'I came here by ka my friends pick me up at my place and dropped me here are 30 minutes to for this casual interview.',
#  "It's ok to be nervous going in 3 exam.",
#  'One use the question the examiner is asking you.',
#  '1 exam ask me.',
# ...

# %%
summary=' '.join(final_summary)

# %%
print(summary)
# Out:
# Ok so arrived today exam centre in our before the start time are you speaking interview. Answer my favourite sport is football because i get the hang out with my friends and get a good workout. 1. 1 year exam asked you question. Find candidates waiting for their exam and ask them to practice with you. Tula the next time you say you ask exam. Initial factors for speaking interview months before your exam. You can people you are not talking about examiner you not talking about people in general. Notice how i started by hair praising the question in using the four question in my answer. Funny time with my family friends. Exam scare the evil speak to month and goa thought. I came here by ka my friends pick me up at my place and dropped me here are 30 minutes to for this casual interview. It's ok to be nervous going in 3 exam. One use the question the examiner is asking you. 1 exam ask me. Start all speak in interview with the time now. Make sure to practice this before your exam. Listen 
# ...

# %%
print(text)
# Out:
# Ao.com ios test preparation videos i would not think she four important strategies. Start all speak in interview with the time now. I will also include example. Phone attend a square band to show you just what to do. Again we have coronavirus skillshare. Overall class plus one from hundreds of different skills of heart by professionals. Whether you're looking to improve your writing work communication in english. Future husband wife quotes. How to succeed in learning a new language. I have been studying cosco product theory with purpose. Sugar i can bring in more videos and content. Temple funny oil exam. Future has given. Especially. In the video description the first 1000 people to sign up via my link. What is this question of premium for one month. For free now. Angela. The first priority to get a perfect and 9 in one is bill. Conference. It's ok to be nervous going in 3 exam. 2 march d conference sc registered speaking. Conference. Initial factors for speaking interview months be
# ...

# %%
print(len(summary))
# Out:
# 2476

# %%
print(len(text))
# Out:
# 5899

# %%
from pydub import AudioSegment 
from pydub.utils import make_chunks 
import datetime
def t(sec):
    return str(datetime.timedelta(seconds=sec))
l=[]
myaudio = AudioSegment.from_file("audio.wav", "wav") 
chunk_length_ms = 10000 # pydub calculates in millisec 
chunks = make_chunks(myaudio,chunk_length_ms) #Make chunks of one sec 
folder_name = "audio-chunk"
if not os.path.isdir(folder_name):
    os.mkdir(folder_name)
for i, chunk in enumerate(chunks):
    chunk_filename = os.path.join(folder_name, f"chunk{i}.wav")
    chunk.export(chunk_filename, format="wav")
    with sr.AudioFile(chunk_filename) as source:
            audio_listened = r.record(source)
            try:
                text = r.recognize_google(audio_listened)
            except sr.UnknownValueError as e:
                print("Error:", str(e))
            else:
                l.append(f"{text.capitalize()}. ")
                #print(chunk_filename, ":", text)
d=["priority","message","confidently","internet","uk","track"]
m=["introduction","Strategy1   ","Strategy2   ","Strategy3   ","Strategy4   ","End         "]
start=0
j=0
for i in range(0,len(l)):
    if j<len(d):
        if d[j] in l[i]:
            end=i*10
            print("{} at [{} to {}] seconds".format(m[j],t(start),t(end)))
            start=i*10
            j=j+1
# Out:
# introduction at [0:00:00 to 0:01:10] seconds
# Strategy1    at [0:01:10 to 0:03:20] seconds
# Strategy2    at [0:03:20 to 0:05:10] seconds
# Strategy3    at [0:05:10 to 0:06:50] seconds
# Strategy4    at [0:06:50 to 0:07:10] seconds
# End          at [0:07:10 to 0:09:20] seconds
