# %%
# !pip install imageio-ffmpeg
# !pip install moviepy
# !pip install pydub
# !pip install speechrecognition
# !pip install spacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.9/dist-packages (0.4.8)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: moviepy in /usr/local/lib/python3.9/dist-packages (1.0.3)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.9/dist-packages (from moviepy) (0.4.8)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/dist-packages (from moviepy) (1.22.4)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.9/dist-packages (from moviepy) (0.1.10)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.9/dist-packages (from moviepy) (2.25.1)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.9/dist-packages (from moviepy) (4.65.0)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from moviepy) (2.27.1)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.9/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.9/dist-packages (from imageio<3.0,>=2.5->moviepy) (8.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0,>=2.8.1->moviepy) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2.0.12)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting speechrecognition
#   Downloading SpeechRecognition-3.10.0-py2.py3-none-any.whl (32.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 29.0 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.9/dist-packages (from speechrecognition) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26.0->speechrecognition) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26.0->speechrecognition) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26.0->speechrecognition) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26.0->speechrecognition) (2.0.12)
# Installing collected packages: speechrecognition
# Successfully installed speechrecognition-3.10.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.9/dist-packages (3.5.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy) (8.1.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (2.27.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.1.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.10.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy) (2.4.6)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (23.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (4.65.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.1.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from spacy) (67.6.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.22.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.9/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy) (2.1.2)

# %%
pip install imageio-ffmpeg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.9/dist-packages (0.4.8)

# %%
# !pip uninstall moviepy
# !pip uninstall imageio-ffmpeg
# !pip install imageio-ffmpeg
# !pip install moviepy
# Out:
# Found existing installation: moviepy 1.0.3
# Uninstalling moviepy-1.0.3:
#   Would remove:
#     /usr/local/lib/python3.9/dist-packages/moviepy-1.0.3.dist-info/*
#     /usr/local/lib/python3.9/dist-packages/moviepy/*
# Proceed (Y/n)? y
#   Successfully uninstalled moviepy-1.0.3
# Found existing installation: imageio-ffmpeg 0.4.8
# Uninstalling imageio-ffmpeg-0.4.8:
#   Would remove:
#     /usr/local/lib/python3.9/dist-packages/imageio_ffmpeg-0.4.8.dist-info/*
#     /usr/local/lib/python3.9/dist-packages/imageio_ffmpeg/*
# Proceed (Y/n)? y
#   Successfully uninstalled imageio-ffmpeg-0.4.8
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting imageio-ffmpeg
#   Downloading imageio_ffmpeg-0.4.8-py3-none-manylinux2010_x86_64.whl (26.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 21.0 MB/s eta 0:00:00
# Installing collected packages: imageio-ffmpeg
# Successfully installed imageio-ffmpeg-0.4.8
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting moviepy
#   Downloading moviepy-1.0.3.tar.gz (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.3/388.3 KB 25.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.9/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.9/dist-packages (from moviepy) (4.65.0)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from moviepy) (2.27.1)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.9/dist-packages (from moviepy) (0.1.10)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/dist-packages (from moviepy) (1.22.4)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.9/dist-packages (from moviepy) (2.25.1)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /usr/local/lib/python3.9/dist-packages (from moviepy) (0.4.8)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.9/dist-packages (from imageio<3.0,>=2.5->moviepy) (8.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0,>=2.8.1->moviepy) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2.0.12)
# Building wheels for collected packages: moviepy
#   Building wheel for moviepy (setup.py) ... done
#   Created wheel for moviepy: filename=moviepy-1.0.3-py3-none-any.whl size=110743 sha256=090b03a3766c0e38dba5b9702b00dc8f9fe0613b5e7fa1806700f364e7e5f712
#   Stored in directory: /root/.cache/pip/wheels/29/15/e4/4f790bec6acd51a00b67e8ee1394f0bc6e0135c315f8ff399a
# Successfully built moviepy
# Installing collected packages: moviepy
# Successfully installed moviepy-1.0.3

# %%
# !pip install SpeechRecognition
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: SpeechRecognition in /usr/local/lib/python3.9/dist-packages (3.10.0)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.9/dist-packages (from SpeechRecognition) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26.0->SpeechRecognition) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26.0->SpeechRecognition) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26.0->SpeechRecognition) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26.0->SpeechRecognition) (2.0.12)

# %%
# !pip install pydub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pydub in /usr/local/lib/python3.9/dist-packages (0.25.1)

# %%
import os
import moviepy.editor as mp
import speech_recognition as sr 
from pydub import AudioSegment
from pydub.silence import split_on_silence
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation
from heapq import nlargest
import datetime
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
# Load the English language model
nlp = spacy.load('en_core_web_sm')

# %%
# Define a function to transcribe a large audio file
def get_large_audio_transcription(path):
    # Load the audio file
    sound = AudioSegment.from_file(path, format="mp4")
    sound.export("/content/drive/MyDrive/PROJECTS/video analysis/audio.wav", format="wav")
    audio = AudioSegment.from_wav("/content/drive/MyDrive/PROJECTS/video analysis/audio.wav")

    # Split the audio into chunks based on silence
    chunks = split_on_silence(audio,
        min_silence_len=500,
        silence_thresh=audio.dBFS-14,
        keep_silence=500,
    )
    r = sr.Recognizer()

    # Create a directory to store the audio chunks
    folder_name = "audio-chunks"
    if not os.path.isdir(folder_name):
        os.mkdir(folder_name)

    # Transcribe each chunk using Google Speech Recognition
    transcript = ""
    for i, audio_chunk in enumerate(chunks, start=1):
        chunk_filename = os.path.join(folder_name, f"chunk{i}.wav")
        audio_chunk.export(chunk_filename, format="wav")
        with sr.AudioFile(chunk_filename) as source:
            audio_listened = r.record(source)
            try:
                text = r.recognize_google(audio_listened)
            except sr.UnknownValueError as e:
                print("Error:", str(e))
            else:
                text = f"{text.capitalize()}. "
                transcript += text

    return transcript

# %%
# Generate the transcript
transcript = get_large_audio_transcription("/content/drive/MyDrive/PROJECTS/video analysis/plate-tectonics-and-california-geology-y2bs.com.mp4")
# Out:
# Error:

# %%
with open("/content/drive/MyDrive/PROJECTS/video analysis/transcript.txt", "w") as f:
    f.write(transcript)

# %%
print(transcript)
# Out:
# So now we have the basics down for plate tectonics. What it is how it works and how we know about it so what. How does plate tectonics affect life in california or anywhere else for that matter. To answer that let's look at california's current plate tectonic setting. Is this map shows we have a number of plate boundaries within or near the state. Notice of the northern part of california we have a divergent plate boundary or an offshore seafloor spreading centre where new oceanic crust forms and then is pushed away. Here along the coast that crust collides with and then sings on the northern california. That produces a convergent plate. Reply with an oceanic crust leading-edge collides with the plate with continental crust on the edge. Result. Seduction. A trench earthquakes and inland active china volcanoes. This volcanic chain is known as the cascade mountains. And in california is expressed with the active volcanoes of mt lassen and mount shasta. The most recent eruption in an area was the explosive eruption depicted in this image of mount lassen on may 22nd 1915. What happens to the seafloor spreading centre off northern california. Like or such centres it is offset at regular intervals by transport box. If you move along the ridge north we hit this transform band. That then connect to the continuation of the spreading centres a bit west. If we go back and follow the ridge south we hit another transform. This one are sets the ridge eastwood. Where. Oh the way south to the sea of cortez where connect with the seafloor spreading centres that are separating the baja peninsula from the rest of mexico. This long transport boundary that connects these two sections of ocean ridge is known as the san andreas fault system. Those of us who live along its path a familiar with its associated earthquake hazards. The loma prieta earthquake in 1989. Was one of the most recent large earthquake. The magnitude 6.9 earthquake cause significant shaking and damage from santa cruz to san francisco as it released built up stress related to the transform plate motion. Why is the transform so long. What made it this way and why they seafloor spreading centre so close to the cotton and not in the middle of the ocean. This animation from the university of santa barbara shows with the pacific ocean look like 80 million years ago when the midleton register for spreading centre with always offset transport. Was actually close to the middle of the ocean. Notice what has happened over the past 80 million years. Is the atlantic ocean spread north america was pushed westwood. The western continental margin of north america with a large long subduction zone with associated volcanoes and terrain accretion. Brought out 25 million years ago the spreading centre began to be overrun. It's a dating on the north american continent. The san andreas fault system began to form. Pause now. Seduction now over the volcanism of this year nevada also ended. But what happened to that spreading. We can image the cross on a north america and see evidence of the old plates still seductive. And right above the start where we suspected spreading centre would now be we have an area of 10. With a condom cross has been pulled apart. Similar to the breakup of pangaea. The crystal stretching has created some parallel mountains and valleys collectively known as the basin and range. I'm on the westernmost edge the sierra nevada mountains are being pulled up out of the ground causing high rates of erosion and exposure of deep granite rock parties that are there now frozen remnants of the magma chambers that used to feed the active subduction volcanoes. So walking in glacier lee card yosemite. Is actually walking along the remnants of all volcanic cores. What else results from the stretching of the basin and range. In addition to exposing the eroded underbelly of ancient syrian vulcan. The roosting activity is also producing a source of new volcanism to the area. The resulting volcanoe ...

# %%
len(transcript)
# Out:
# 7248

# %%
import wave
import numpy as np
import matplotlib.pyplot as plt
audio_file = wave.open("/content/drive/MyDrive/PROJECTS/video analysis/audio.wav", "rb")
frames = audio_file.readframes(-1)

sample_rate = audio_file.getframerate()
num_channels = audio_file.getnchannels()

audio_array = np.frombuffer(frames, dtype=np.int16)

if num_channels > 1:
    audio_array = np.mean(audio_array.reshape(-1, num_channels), axis=1)

time_axis = np.linspace(0, len(audio_array) / sample_rate, num=len(audio_array))

# %%
plt.plot(time_axis, audio_array)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.show()

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.9/dist-packages (3.5.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.1.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.22.4)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (2.27.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (4.65.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (23.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.10.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from spacy) (67.6.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.1.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy) (8.1.9)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy) (2.4.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.9/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy) (2.1.2)
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-03-26 18:26:34.925854: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-26 18:26:34.925992: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-26 18:26:34.926020: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-03-26 18:26:36.993305: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 44.8 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.9/dist-packages (from en-core-web-sm==3.5.0) (3.5.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.22.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.7)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.65.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.27.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (67.6.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (23.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2022.12.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.9/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import heapq
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
# Load transcribed text from video
with open("/content/drive/MyDrive/PROJECTS/video analysis/transcript.txt", "r") as f:
    text = f.read()

# %%
# Convert text to sentences
doc = nlp(text)
sentences = [sent.text for sent in doc.sents]
sentences
# Out:
# ['So now we have the basics down for plate tectonics.',
#  'What it is how it works and how we know about it',
#  'so what.',
#  'How does plate tectonics affect life in california or anywhere else for that matter.',
#  "To answer that let's look at california's current plate tectonic setting.",
#  'Is this map shows we have a number of plate boundaries within or near the state.',
#  'Notice of the northern part of california we have a divergent plate boundary or an offshore seafloor spreading centre where new oceanic crust forms and then is pushed away.',
#  'Here along the coast that crust collides with and then sings on the northern california.',
#  'That produces a convergent plate.',
#  'Reply with an oceanic crust leading-edge collides with the plate with continental crust on the edge.',
#  'Result.',
#  'Seduction.',
#  'A trench earthquakes and inland active china volcanoes.',
#  'This volcanic chain is known as the cascade mountains.',
#  'And in california is expressed with the active volcanoes of mt lassen and mount shasta.',
#  'The most recent eruption in an area was the explosive eruption depicted in this image of mount lassen on may 22nd 1915.',
#  'What happens to the seafloor spreading centre off northern california.',
#  'Like or such centres it is offset at regular intervals by transport box.',
#  'If you move along the ridge north we hit this transform band.',
#  'That then connect to the continuation of the spreading centres a bit west.',
#  'If we go back and follow the ridge south we hit another transform.',
#  'This one are sets the ridge eastwood.',
#  'Where.',
#  'Oh the way south to the sea of cortez where connect with the seafloor spreading centres that are separating the baja peninsula from the rest of mexico.',
#  'This long transport boundary that connects these two sections of ocean ridge is known as the san andreas fault system.',
#  'Those of us who live along its path a familiar with its associated earthquake hazards.',
#  'The loma prieta earthquake in 1989.',
#  'Was one of the most recent large earthquake.',
#  'The magnitude 6.9 earthquake cause significant shaking and damage from santa cruz to san francisco as it released built up stress related to the transform plate motion.',
#  'Why is the transform so long.',
#  'What made it this way and why they seafloor spreading centre so close to the cotton and not in the middle of the ocean.',
#  'This animation from the university of santa barbara shows with the pacific ocean look like 80 million years ago when the midleton register for spreading centre with always offset transport.',
#  'Was actually close to the middle of the ocean.',
#  'Notice what has happened over the past 80 million years.',
#  'Is the atlantic ocean spread north america was pushed westwood.',
#  'The western continental margin of north america with a large long subduction zone with associated volcanoes and terrain accretion.',
#  'Brought out 25 million years ago the spreading centre began to be overrun.',
#  "It's a dating on the north american continent.",
#  'The san andreas fault system began to form.',
#  'Pause now.',
#  'Seduction now over the volcanism of this year nevada also ended.',
#  'But what happened to that spreading.',
#  'We can image the cross on a north america and see evidence of the old plates still seductive.',
#  'And right above the start where we suspected spreading centre would now be we have an area of 10.',
#  'With a condom cross has been pulled apart.',
#  'Similar to the breakup of pangaea.',
#  'The crystal stretching has created some parallel mountains and valleys collectively known as the basin and range.',
#  "I'm on the westernmost edge the sierra nevada mountains are being pulled up out of the ground causing high rates of erosion and exposure of deep granite rock parties that are there now frozen remnants of the magma chambers that used to feed the active subduction volcanoes.",
#  'So walking in glacier lee card yosemite.',
#  'Is actually walking along the remnants of all volcanic cores.',
#  'What else results from the stretching of the basin and range.',
#  'In addition to exposing the eroded underbelly of ancient syrian vulcan.',
#  'The roosting activity is also producing a source of new volcanism to the area.',
#  'The resulting volcanoes are completely different in character and cars to subduction zone volcanoes.',
#  'Ghost binding more voluminous cinema supply.',
#  'A more explosive in eruptive style.',
#  'Mammoth mountain is 1 volcanic structure found in the middle of this region known collectively as long valley.',
#  'In this region of rifting and thin crust mantle rock is melting in rising beneath the surface just like what happens at sea for spreading divergent plate boundaries.',
#  'Mental maths combined with large amounts of crust on.',
#  'Collecting a giant magma chamber just under the surface.',
#  'The long valley caldera is a giant crater left behind after one of the largest volcanic eruptions to happen in north america.',
#  'Emptied the magma chamber and the surrounding crash collapsed.',
#  'The last eruption about 760000 years ago last bits of strewn across most of the western united states.',
#  "There's still an active magma chamber under the caldera which releases carbon dioxide gases and hot water in numerous locations around the room.",
#  'It has been classified as one of the largest volcanic centres in north america.',
#  'The most recent eruptions were those that produced panam crater and the in your creator.',
#  '500 to 600 years ago.',
#  "Let's leave this unique volcanic region and return to the remnants of the ancient seduction.com volcanoes now exposes granite in the central and western series.",
#  'If you want to experience some of this.',
#  'The sender is fault is done a great job of moving rocks around in the sea.',
#  'As a result of the transfer motion sections of the southern sierra nevada granite were separated from their originations for interiors northwich.',
#  'Received them today as far north as raise.',
#  'They also make up the rock of montana.',
#  'And the rock at the fairmont ireland.',
#  'Pause now.',
#  'What about the rest of the rock around us where did that come.',
#  'Well some of the rock that makes up the santa cruz mountains in the hills of san francisco.',
#  'Times of coastal sediments during changing sea levels and ice ages the majority of it consists of individual blocks of terrains that were created during the past periods of seduction.',
#  'Prior to the collision of a mid-ocean ridge with a subduction zones there were hundreds of millions of years of active seduction.',
#  "During that time oceancraft was carried into the subduction zones and portions of audit carried were scraped off and attached to the edge of the can't.",
#  'Extending the continent westwood in a paper mache style sequence of edition or accretion.',
#  'A cream material can include ocean sediment they got scraped off the top of the subducting plate.',
#  'Carnival sediment that would have pulled off the continental shelf into the trench ocean sea monster island that would have gotten stuck in a trench and scraped off sections of the entire oceanic crust.',
#  'And metamorphic rocks produced during collision and seduction.',
#  'As you can see plate tectonics has had a huge impact on a past and present landscape of california.',
#  'It produces many of our major geologic hazards and it is rafting in and then combined the very land masses that now make-up estate.',
#  'Take a field trip to one of these near my location.',
#  'Well you can see the evidence and walk on the old surfaces yourself.',
#  'Pause now.',
#  'For more information in more detail continue onto the next video in the series.']

# %%
tokens = [token.text for token in doc]
print(tokens)
# Out:
# ['So', 'now', 'we', 'have', 'the', 'basics', 'down', 'for', 'plate', 'tectonics', '.', 'What', 'it', 'is', 'how', 'it', 'works', 'and', 'how', 'we', 'know', 'about', 'it', 'so', 'what', '.', 'How', 'does', 'plate', 'tectonics', 'affect', 'life', 'in', 'california', 'or', 'anywhere', 'else', 'for', 'that', 'matter', '.', 'To', 'answer', 'that', 'let', "'s", 'look', 'at', 'california', "'s", 'current', 'plate', 'tectonic', 'setting', '.', 'Is', 'this', 'map', 'shows', 'we', 'have', 'a', 'number', 'of', 'plate', 'boundaries', 'within', 'or', 'near', 'the', 'state', '.', 'Notice', 'of', 'the', 'northern', 'part', 'of', 'california', 'we', 'have', 'a', 'divergent', 'plate', 'boundary', 'or', 'an', 'offshore', 'seafloor', 'spreading', 'centre', 'where', 'new', 'oceanic', 'crust', 'forms', 'and', 'then', 'is', 'pushed', 'away', '.', 'Here', 'along', 'the', 'coast', 'that', 'crust', 'collides', 'with', 'and', 'then', 'sings', 'on', 'the', 'northern', 'california', '.', 'That', 'produces', 'a', 'convergent', 'plate', '.', 'Reply', 'with', 'an', 'oceanic', 'crust', 'leading', '-', 'edge', 'collides', 'with', 'the', 'plate', 'with', 'continental', 'crust', 'on', 'the', 'edge', '.', 'Result', '.', 'Seduction', '.', 'A', 'trench', 'earthquakes', 'and', 'inland', 'active', 'china', 'volcanoes', '.', 'This', 'volcanic', 'chain', 'is', 'known', 'as', 'the', 'cascade', 'mountains', '.', 'And', 'in', 'california', 'is', 'expressed', 'with', 'the', 'active', 'volcanoes', 'of', 'mt', 'lassen', 'and', 'mount', 'shasta', '.', 'The', 'most', 'recent', 'eruption', 'in', 'an', 'area', 'was', 'the', 'explosive', 'eruption', 'depicted', 'in', 'this', 'image', 'of', 'mount', 'lassen', 'on', 'may', '22nd', '1915', '.', 'What', 'happens', 'to', 'the', 'seafloor', 'spreading', 'centre', 'off', 'northern', 'california', '.', 'Like', 'or', 'such', 'centres', 'it', 'is', 'offset', 'at', 'regular', 'intervals', 'by', 'transport', 'box', '.', 'If', 'you', 'move', 'along', 'the', 'ridge', 'north', 'we', 'hit', 'this', 'transform', 'band', '.', 'That', 'then', 'connect', 'to', 'the', 'continuation', 'of', 'the', 'spreading', 'centres', 'a', 'bit', 'west', '.', 'If', 'we', 'go', 'back', 'and', 'follow', 'the', 'ridge', 'south', 'we', 'hit', 'another', 'transform', '.', 'This', 'one', 'are', 'sets', 'the', 'ridge', 'eastwood', '.', 'Where', '.', 'Oh', 'the', 'way', 'south', 'to', 'the', 'sea', 'of', 'cortez', 'where', 'connect', 'with', 'the', 'seafloor', 'spreading', 'centres', 'that', 'are', 'separating', 'the', 'baja', 'peninsula', 'from', 'the', 'rest', 'of', 'mexico', '.', 'This', 'long', 'transport', 'boundary', 'that', 'connects', 'these', 'two', 'sections', 'of', 'ocean', 'ridge', 'is', 'known', 'as', 'the', 'san', 'andreas', 'fault', 'system', '.', 'Those', 'of', 'us', 'who', 'live', 'along', 'its', 'path', 'a', 'familiar', 'with', 'its', 'associated', 'earthquake', 'hazards', '.', 'The', 'loma', 'prieta', 'earthquake', 'in', '1989', '.', 'Was', 'one', 'of', 'the', 'most', 'recent', 'large', 'earthquake', '.', 'The', 'magnitude', '6.9', 'earthquake', 'cause', 'significant', 'shaking', 'and', 'damage', 'from', 'santa', 'cruz', 'to', 'san', 'francisco', 'as', 'it', 'released', 'built', 'up', 'stress', 'related', 'to', 'the', 'transform', 'plate', 'motion', '.', 'Why', 'is', 'the', 'transform', 'so', 'long', '.', 'What', 'made', 'it', 'this', 'way', 'and', 'why', 'they', 'seafloor', 'spreading', 'centre', 'so', 'close', 'to', 'the', 'cotton', 'and', 'not', 'in', 'the', 'middle', 'of', 'the', 'ocean', '.', 'This', 'animation', 'from', 'the', 'university', 'of', 'santa', 'barbara', 'shows', 'with', 'the', 'pacific', 'ocean', 'look', 'like', '80', 'million', 'years', 'ago', 'when', 'the', 'midleton', 'register', 'for', 'spreading', 'centre', 'with', 'always', 'offset', 'transport', '.', 'Was', 'actually', 'close', 'to', 'the', 'middle', 'of', 'the', 'ocean', '.', 'Notice', 'what', 'has', 'happened', 'over', 'the', 'past', '80', 'million', 'years', '.', 'Is', 'the ...

# %%
doc
# Out:
# So now we have the basics down for plate tectonics. What it is how it works and how we know about it so what. How does plate tectonics affect life in california or anywhere else for that matter. To answer that let's look at california's current plate tectonic setting. Is this map shows we have a number of plate boundaries within or near the state. Notice of the northern part of california we have a divergent plate boundary or an offshore seafloor spreading centre where new oceanic crust forms and then is pushed away. Here along the coast that crust collides with and then sings on the northern california. That produces a convergent plate. Reply with an oceanic crust leading-edge collides with the plate with continental crust on the edge. Result. Seduction. A trench earthquakes and inland active china volcanoes. This volcanic chain is known as the cascade mountains. And in california is expressed with the active volcanoes of mt lassen and mount shasta. The most recent eruption in an area was the explosive eruption depicted in this image of mount lassen on may 22nd 1915. What happens to the seafloor spreading centre off northern california. Like or such centres it is offset at regular intervals by transport box. If you move along the ridge north we hit this transform band. That then connect to the continuation of the spreading centres a bit west. If we go back and follow the ridge south we hit another transform. This one are sets the ridge eastwood. Where. Oh the way south to the sea of cortez where connect with the seafloor spreading centres that are separating the baja peninsula from the rest of mexico. This long transport boundary that connects these two sections of ocean ridge is known as the san andreas fault system. Those of us who live along its path a familiar with its associated earthquake hazards. The loma prieta earthquake in 1989. Was one of the most recent large earthquake. The magnitude 6.9 earthquake cause significant shaking and damage from santa cruz to san francisco as it released built up stress related to the transform plate motion. Why is the transform so long. What made it this way and why they seafloor spreading centre so close to the cotton and not in the middle of the ocean. This animation from the university of santa barbara shows with the pacific ocean look like 80 million years ago when the midleton register for spreading centre with always offset transport. Was actually close to the middle of the ocean. Notice what has happened over the past 80 million years. Is the atlantic ocean spread north america was pushed westwood. The western continental margin of north america with a large long subduction zone with associated volcanoes and terrain accretion. Brought out 25 million years ago the spreading centre began to be overrun. It's a dating on the north american continent. The san andreas fault system began to form. Pause now. Seduction now over the volcanism of this year nevada also ended. But what happened to that spreading. We can image the cross on a north america and see evidence of the old plates still seductive. And right above the start where we suspected spreading centre would now be we have an area of 10. With a condom cross has been pulled apart. Similar to the breakup of pangaea. The crystal stretching has created some parallel mountains and valleys collectively known as the basin and range. I'm on the westernmost edge the sierra nevada mountains are being pulled up out of the ground causing high rates of erosion and exposure of deep granite rock parties that are there now frozen remnants of the magma chambers that used to feed the active subduction volcanoes. So walking in glacier lee card yosemite. Is actually walking along the remnants of all volcanic cores. What else results from the stretching of the basin and range. In addition to exposing the eroded underbelly of ancient syrian vulcan. The roosting activity is also producing a source of new volcanism to the area. The resulting volcanoe ...

# %%
# Calculate sentence scores based on word frequency
word_frequencies = {}
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation
for word in doc:
    if word.text.lower() not in STOP_WORDS:
        if word.text.lower() not in word_frequencies.keys():
            word_frequencies[word.text.lower()] = 1
        else:
            word_frequencies[word.text.lower()] += 1

# %%
STOP_WORDS
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mine',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myself',
#  "n't",
#  'name',
#  'namely',
#  'neither',
#  'never',
#  'nevertheless',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'none',
#  'noone',
#  'nor',
#  'not',
#  'nothing',
#  'now',
#  'nowhere',
#  'n‘t',
#  'n’t',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  'very',
#  'via',
#  'was',
#  'we',
#  'well',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '‘d',
#  '‘ll',
#  '‘m',
#  '‘re',
#  '‘s',
#  '‘ve',
#  '’d',
#  '’ll',
#  '’m',
#  '’re',
#  '’s',
#  '’ve'}

# %%
word_frequencies
# Out:
# {'basics': 1,
#  'plate': 11,
#  'tectonics': 3,
#  '.': 89,
#  'works': 1,
#  'know': 1,
#  'affect': 1,
#  'life': 1,
#  'california': 7,
#  'matter': 1,
#  'answer': 1,
#  'let': 2,
#  'look': 2,
#  'current': 1,
#  'tectonic': 1,
#  'setting': 1,
#  'map': 1,
#  'shows': 2,
#  'number': 1,
#  'boundaries': 2,
#  'near': 2,
#  'state': 1,
#  'notice': 2,
#  'northern': 3,
#  'divergent': 2,
#  'boundary': 2,
#  'offshore': 1,
#  'seafloor': 4,
#  'spreading': 10,
#  'centre': 6,
#  'new': 2,
#  'oceanic': 3,
#  'crust': 7,
#  'forms': 1,
#  'pushed': 2,
#  'away': 1,
#  'coast': 1,
#  'collides': 2,
#  'sings': 1,
#  'produces': 2,
#  'convergent': 1,
#  'reply': 1,
#  'leading': 1,
#  '-': 3,
#  'edge': 4,
#  'continental': 3,
#  'result': 2,
#  'seduction': 5,
#  'trench': 3,
#  'earthquakes': 1,
#  'inland': 1,
#  'active': 5,
#  'china': 1,
#  'volcanoes': 7,
#  'volcanic': 6,
#  'chain': 1,
#  'known': 4,
#  'cascade': 1,
#  'mountains': 4,
#  'expressed': 1,
#  'mt': 1,
#  'lassen': 2,
#  'mount': 2,
#  'shasta': 1,
#  'recent': 3,
#  'eruption': 3,
#  'area': 3,
#  'explosive': 2,
#  'depicted': 1,
#  'image': 2,
#  '22nd': 1,
#  '1915': 1,
#  'happens': 2,
#  'like': 3,
#  'centres': 4,
#  'offset': 2,
#  'regular': 1,
#  'intervals': 1,
#  'transport': 3,
#  'box': 1,
#  'ridge': 5,
#  'north': 8,
#  'hit': 2,
#  'transform': 4,
#  'band': 1,
#  'connect': 2,
#  'continuation': 1,
#  'bit': 1,
#  'west': 1,
#  'follow': 1,
#  'south': 2,
#  'sets': 1,
#  'eastwood': 1,
#  'oh': 1,
#  'way': 2,
#  'sea': 5,
#  'cortez': 1,
#  'separating': 1,
#  'baja': 1,
#  'peninsula': 1,
#  'rest': 2,
#  'mexico': 1,
#  'long': 5,
#  'connects': 1,
#  'sections': 3,
#  'ocean': 8,
#  'san': 4,
#  'andreas': 2,
#  'fault': 3,
#  'system': 2,
#  'live': 1,
#  'path': 1,
#  'familiar': 1,
#  'associated': 2,
#  'earthquake': 4,
#  'hazards': 2,
#  'loma': 1,
#  'prieta': 1,
#  '1989': 1,
#  'large': 3,
#  'magnitude': 1,
#  '6.9': 1,
#  'cause': 1,
#  'significant': 1,
#  'shaking': 1,
#  'damage': 1,
#  'santa': 3,
#  'cruz': 2,
#  'francisco': 2,
#  'released': 1,
#  'built': 1,
#  'stress': 1,
#  'related': 1,
#  'motion': 2,
#  'close': 2,
#  'cotton': 1,
#  'middle': 3,
#  'animation': 1,
#  'university': 1,
#  'barbara': 1,
#  'pacific': 1,
#  '80': 2,
#  'million': 3,
#  'years': 6,
#  'ago': 4,
#  'midleton': 1,
#  'register': 1,
#  'actually': 2,
#  'happened': 2,
#  'past': 3,
#  'atlantic': 1,
#  'spread': 1,
#  'america': 5,
#  'westwood': 2,
#  'western': 3,
#  'margin': 1,
#  'subduction': 5,
#  'zone': 2,
#  'terrain': 1,
#  'accretion': 2,
#  'brought': 1,
#  '25': 1,
#  'began': 2,
#  'overrun': 1,
#  'dating': 1,
#  'american': 1,
#  'continent': 2,
#  'form': 1,
#  'pause': 3,
#  'volcanism': 2,
#  'year': 1,
#  'nevada': 3,
#  'ended': 1,
#  'cross': 2,
#  'evidence': 2,
#  'old': 2,
#  'plates': 1,
#  'seductive': 1,
#  'right': 1,
#  'start': 1,
#  'suspected': 1,
#  '10': 1,
#  'condom': 1,
#  'pulled': 3,
#  'apart': 1,
#  'similar': 1,
#  'breakup': 1,
#  'pangaea': 1,
#  'crystal': 1,
#  'stretching': 2,
#  'created': 2,
#  'parallel': 1,
#  'valleys': 1,
#  'collectively': 2,
#  'basin': 2,
#  'range': 2,
#  'westernmost': 1,
#  'sierra': 2,
#  'ground': 1,
#  'causing': 1,
#  'high': 1,
#  'rates': 1,
#  'erosion': 1,
#  'exposure': 1,
#  'deep': 1,
#  'granite': 3,
#  'rock': 6,
#  'parties': 1,
#  'frozen': 1,
#  'remnants': 3,
#  'magma': 4,
#  'chambers': 1,
#  'feed': 1,
#  'walking': 2,
#  'glacier': 1,
#  'lee': 1,
#  'card': 1,
#  'yosemite': 1,
#  'cores': 1,
#  'results': 1,
#  'addition': 1,
#  'exposing': 1,
#  'eroded': 1,
#  'underbelly': 1,
#  'ancient': 2,
#  'syrian': 1,
#  'vulcan': 1,
#  'roosting': 1,
#  'activity': 1,
#  'producing': 1,
#  'source': 1,
#  'resulting': 1,
#  'completely': 1,
#  'different': 1,
#  'character': 1,
#  'cars': 1,
#  'ghost': 1,
#  'binding': 1,
#  'voluminous': 1,
#  'cinema': 1,
#  'supply': 1,
#  'eruptive': 1,
#  'style': 2,
#  'mammoth': 1,
#  'mountain': 1,
#  '1': 1,
#  'structure': 1,
#  'found': 1,
#  'region': 3,
#  'valley': 2,
#  'rifting': 1,
#  'thin': 1,
#  'mantle': 1,
#  'melting': 1,
#  'rising': 1,
#  'beneath': 1,
#  'surface': 2,
#  'mental': 1,
#  'maths': 1,
#  'combined': 2,
#  'amounts': 1,
#  'collecting': 1,
#  'giant': 2,
#  'chamber': 3,
#  'caldera': 2,
#  'crater': 2,
#  'left': 1,
#  'largest': 2,
#  'eruptions': 2,
#  'happen': 1,
#  'emptied': 1,
#  'surrounding': 1,
#  'crash': 1,
#  'collapsed': 1,
#  '760000': 1,
#  'bits': 1,
#  'strewn': 1,
#  'united': 1,
#  'states': 1,
#  'releases': 1,
#  'carbon': 1,
#  'dioxide': 1,
#  'gases': 1,
#  'hot': 1,
#  'water': 1,
#  'numerous': 1,
#  'locations': 1,
#  'room': 1,
#  'classified': 1,
#  'produced': 2,
#  'panam': 1,
#  'creator': 1,
#  '500': 1,
#  '600': 1,
#  'leave': 1,
#  'unique': 1,
#  'return': 1,
#  'seduction.com': 1,
#  'exposes': 1,
#  'central': 1,
#  'series': 2,
#  'want': 1,
#  'experience': 1,
#  'sender': 1,
#  'great': 1,
#  'job': 1,
#  'moving': 1,
#  'rocks': 2,
#  'transfer': 1,
#  'southern': 1,
#  'separated': 1,
#  'originations': 1,
#  'interiors': 1,
#  'northwich': 1,
#  'received': 1,
#  'today': 1,
#  'far': 1,
#  'raise': 1,
#  'montana': 1,
#  'fairmont': 1,
#  'ireland': 1,
#  'come': 1,
#  'makes': 1,
#  'hills': 1,
#  'times': 1,
#  'coastal': 1,
#  'sediments': 1,
#  'changing': 1,
#  'levels': 1,
#  'ice': 1,
#  'ages': 1,
#  'majority': 1,
#  'consists': 1,
#  'individual': 1,
#  'blocks': 1,
#  'terrains': 1,
#  'periods': 1,
#  'prior': 1,
#  'collision': 2,
#  'mid': 1,
#  'zones': 2,
#  'hundreds': 1,
#  'millions': 1,
#  'time': 1,
#  'oceancraft': 1,
#  'carried': 2,
#  'portions': 1,
#  'audit': 1,
#  'scraped': 3,
#  'attached': 1,
#  'extending': 1,
#  'paper': 1,
#  'mache': 1,
#  'sequence': 1,
#  'edition': 1,
#  'cream': 1,
#  'material': 1,
#  'include': 1,
#  'sediment': 2,
#  'got': 1,
#  'subducting': 1,
#  'carnival': 1,
#  'shelf': 1,
#  'monster': 1,
#  'island': 1,
#  'gotten': 1,
#  'stuck': 1,
#  'entire': 1,
#  'metamorphic': 1,
#  'huge': 1,
#  'impact': 1,
#  'present': 1,
#  'landscape': 1,
#  'major': 1,
#  'geologic': 1,
#  'rafting': 1,
#  'land': 1,
#  'masses': 1,
#  'estate': 1,
#  'field': 1,
#  'trip': 1,
#  'location': 1,
#  'walk': 1,
#  'surfaces': 1,
#  'information': 1,
#  'detail': 1,
#  'continue': 1,
#  'video': 1}

# %%
max_frequency = max(word_frequencies.values())
for word in word_frequencies.keys():
    word_frequencies[word] = (word_frequencies[word]/max_frequency)

# %%
max_frequency
# Out:
# 89

# %%
sentence_scores = {}
for sent in sentences:
    for word in sent.split():
        if word.lower() in word_frequencies.keys():
            if len(sent.split(' ')) < 30:
                if sent not in sentence_scores.keys():
                    sentence_scores[sent] = word_frequencies[word.lower()]
                else:
                    sentence_scores[sent] += word_frequencies[word.lower()]

# %%
sentence_scores
# Out:
# {'So now we have the basics down for plate tectonics.': 0.1348314606741573,
#  'What it is how it works and how we know about it': 0.02247191011235955,
#  'How does plate tectonics affect life in california or anywhere else for that matter.': 0.2584269662921348,
#  "To answer that let's look at california's current plate tectonic setting.": 0.1797752808988764,
#  'Is this map shows we have a number of plate boundaries within or near the state.': 0.21348314606741572,
#  'Notice of the northern part of california we have a divergent plate boundary or an offshore seafloor spreading centre where new oceanic crust forms and then is pushed away.': 0.7078651685393258,
#  'Here along the coast that crust collides with and then sings on the northern california.': 0.15730337078651685,
#  'That produces a convergent plate.': 0.033707865168539325,
#  'Reply with an oceanic crust leading-edge collides with the plate with continental crust on the edge.': 0.3820224719101123,
#  'A trench earthquakes and inland active china volcanoes.': 0.12359550561797752,
#  'This volcanic chain is known as the cascade mountains.': 0.1348314606741573,
#  'And in california is expressed with the active volcanoes of mt lassen and mount shasta.': 0.28089887640449435,
#  'The most recent eruption in an area was the explosive eruption depicted in this image of mount lassen on may 22nd 1915.': 0.24719101123595505,
#  'What happens to the seafloor spreading centre off northern california.': 0.2808988764044944,
#  'Like or such centres it is offset at regular intervals by transport box.': 0.15730337078651685,
#  'If you move along the ridge north we hit this transform band.': 0.21348314606741572,
#  'That then connect to the continuation of the spreading centres a bit west.': 0.20224719101123595,
#  'If we go back and follow the ridge south we hit another transform.': 0.11235955056179775,
#  'This one are sets the ridge eastwood.': 0.06741573033707865,
#  'Oh the way south to the sea of cortez where connect with the seafloor spreading centres that are separating the baja peninsula from the rest of mexico.': 0.40449438202247195,
#  'This long transport boundary that connects these two sections of ocean ridge is known as the san andreas fault system.': 0.449438202247191,
#  'Those of us who live along its path a familiar with its associated earthquake hazards.': 0.10112359550561797,
#  'The loma prieta earthquake in 1989.': 0.06741573033707865,
#  'Was one of the most recent large earthquake.': 0.06741573033707865,
#  'The magnitude 6.9 earthquake cause significant shaking and damage from santa cruz to san francisco as it released built up stress related to the transform plate motion.': 0.449438202247191,
#  'Why is the transform so long.': 0.0449438202247191,
#  'What made it this way and why they seafloor spreading centre so close to the cotton and not in the middle of the ocean.': 0.3146067415730337,
#  'Was actually close to the middle of the ocean.': 0.07865168539325842,
#  'Notice what has happened over the past 80 million years.': 0.1348314606741573,
#  'Is the atlantic ocean spread north america was pushed westwood.': 0.28089887640449435,
#  'The western continental margin of north america with a large long subduction zone with associated volcanoes and terrain accretion.': 0.5056179775280899,
#  'Brought out 25 million years ago the spreading centre began to be overrun.': 0.3707865168539326,
#  "It's a dating on the north american continent.": 0.11235955056179775,
#  'The san andreas fault system began to form.': 0.14606741573033707,
#  'Pause now.': 0.10112359550561797,
#  'Seduction now over the volcanism of this year nevada also ended.': 0.12359550561797752,
#  'But what happened to that spreading.': 0.02247191011235955,
#  'We can image the cross on a north america and see evidence of the old plates still seductive.': 0.24719101123595505,
#  'And right above the start where we suspected spreading centre would now be we have an area of 10.': 0.24719101123595505,
#  'With a condom cross has been pulled apart.': 0.06741573033707865,
#  'Similar to the breakup of pangaea.': 0.02247191011235955,
#  'The crystal stretching has created some parallel mountains and valleys collectively known as the basin and range.': 0.21348314606741572,
#  'So walking in glacier lee card yosemite.': 0.056179775280898875,
#  'Is actually walking along the remnants of all volcanic cores.': 0.14606741573033707,
#  'What else results from the stretching of the basin and range.': 0.056179775280898875,
#  'In addition to exposing the eroded underbelly of ancient syrian vulcan.': 0.07865168539325842,
#  'The roosting activity is also producing a source of new volcanism to the area.': 0.0898876404494382,
#  'The resulting volcanoes are completely different in character and cars to subduction zone volcanoes.': 0.21348314606741572,
#  'Ghost binding more voluminous cinema supply.': 0.0449438202247191,
#  'A more explosive in eruptive style.': 0.033707865168539325,
#  'Mammoth mountain is 1 volcanic structure found in the middle of this region known collectively as long valley.': 0.3146067415730337,
#  'In this region of rifting and thin crust mantle rock is melting in rising beneath the surface just like what happens at sea for spreading divergent plate boundaries.': 0.6404494382022471,
#  'Mental maths combined with large amounts of crust on.': 0.16853932584269662,
#  'Collecting a giant magma chamber just under the surface.': 0.11235955056179775,
#  'The long valley caldera is a giant crater left behind after one of the largest volcanic eruptions to happen in north america.': 0.3707865168539326,
#  'Emptied the magma chamber and the surrounding crash collapsed.': 0.11235955056179775,
#  'The last eruption about 760000 years ago last bits of strewn across most of the western united states.': 0.2247191011235955,
#  "There's still an active magma chamber under the caldera which releases carbon dioxide gases and hot water in numerous locations around the room.": 0.24719101123595505,
#  'It has been classified as one of the largest volcanic centres in north america.': 0.23595505617977527,
#  'The most recent eruptions were those that produced panam crater and the in your creator.': 0.11235955056179775,
#  '500 to 600 years ago.': 0.0898876404494382,
#  "Let's leave this unique volcanic region and return to the remnants of the ancient seduction.com volcanoes now exposes granite in the central and western series.": 0.3707865168539326,
#  'If you want to experience some of this.': 0.02247191011235955,
#  'The sender is fault is done a great job of moving rocks around in the sea.': 0.10112359550561797,
#  'As a result of the transfer motion sections of the southern sierra nevada granite were separated from their originations for interiors northwich.': 0.2247191011235955,
#  'Received them today as far north as raise.': 0.12359550561797752,
#  'They also make up the rock of montana.': 0.06741573033707865,
#  'And the rock at the fairmont ireland.': 0.07865168539325842,
#  'What about the rest of the rock around us where did that come.': 0.0898876404494382,
#  'Well some of the rock that makes up the santa cruz mountains in the hills of san francisco.': 0.23595505617977527,
#  'Prior to the collision of a mid-ocean ridge with a subduction zones there were hundreds of millions of years of active seduction.': 0.3146067415730337,
#  "During that time oceancraft was carried into the subduction zones and portions of audit carried were scraped off and attached to the edge of the can't.": 0.2584269662921348,
#  'Extending the continent westwood in a paper mache style sequence of edition or accretion.': 0.12359550561797752,
#  'A cream material can include ocean sediment they got scraped off the top of the subducting plate.': 0.20224719101123595,
#  'And metamorphic rocks produced during collision and seduction.': 0.07865168539325842,
#  'As you can see plate tectonics has had a huge impact on a past and present landscape of california.': 0.23595505617977527,
#  'It produces many of our major geologic hazards and it is rafting in and then combined the very land masses that now make-up estate.': 0.12359550561797752,
#  'Take a field trip to one of these near my location.': 0.0449438202247191,
#  'Well you can see the evidence and walk on the old surfaces yourself.': 0.06741573033707865,
#  'For more information in more detail continue onto the next video in the series.': 0.0449438202247191}

# %%
# Set summarization parameters
percentage = int(input("enter how much percentage you need to read")) # user-specified percentage
max_length = len(sentences) * percentage // 100 # calculate max length of summary

# Generate summary
summary_sentences = heapq.nlargest(max_length, sentence_scores, key=sentence_scores.get)
summary = " ".join(str(sent) for sent in summary_sentences)
print(summary)
# Save summary to file
with open("/content/drive/MyDrive/PROJECTS/video analysis/summary.txt", "w") as f:
    f.write(summary)
# Out:
# enter how much percentage you need to read75
# Notice of the northern part of california we have a divergent plate boundary or an offshore seafloor spreading centre where new oceanic crust forms and then is pushed away. In this region of rifting and thin crust mantle rock is melting in rising beneath the surface just like what happens at sea for spreading divergent plate boundaries. The western continental margin of north america with a large long subduction zone with associated volcanoes and terrain accretion. This long transport boundary that connects these two sections of ocean ridge is known as the san andreas fault system. The magnitude 6.9 earthquake cause significant shaking and damage from santa cruz to san francisco as it released built up stress related to the transform plate motion. Oh the way south to the sea of cortez where connect with the seafloor spreading centres that are separating the baja peninsula from the rest of mexico. Reply with an oceanic crust leading-edge collides with the plate with continental crust on the edge. Brought out 25 million years ago the spreading centre began to be overrun. The long valley caldera is a giant crater left behind after one of the largest volcanic eruptions to happen in north america. Let's leave this unique volcanic region and return to the remnants of the ancient seduction.com volcanoes now exposes granite in the central and western series. What made it this way and why they seafloor spreading centre so close to the cotton and not in the middle of the ocean. Mammoth mountain is 1 volcanic structure found in the middle of this region known collectively as long valley. Prior to the collision of a mid-ocean ridge with a subduction zones there were hundreds of millions of years of active seduction. What happens to the seafloor spreading centre off northern california. And in california is expressed with the active volcanoes of mt lassen and mount shasta. Is the atlantic ocean spread north america was pushed westwood. How does plate tectonics affect life in california or anywhere else for that matter. During that time oceancraft was carried into the subduction zones and portions of audit carried were scraped off and attached to the edge of the can't. The most recent eruption in an area was the explosive eruption depicted in this image of mount lassen on may 22nd 1915. We can image the cross on a north america and see evidence of the old plates still seductive. And right above the start where we suspected spreading centre would now be we have an area of 10. There's still an active magma chamber under the caldera which releases carbon dioxide gases and hot water in numerous locations around the room. It has been classified as one of the largest volcanic centres in north america. Well some of the rock that makes up the santa cruz mountains in the hills of san francisco. As you can see plate tectonics has had a huge impact on a past and present landscape of california. The last eruption about 760000 years ago last bits of strewn across most of the western united states. As a result of the transfer motion sections of the southern sierra nevada granite were separated from their originations for interiors northwich. Is this map shows we have a number of plate boundaries within or near the state. If you move along the ridge north we hit this transform band. The crystal stretching has created some parallel mountains and valleys collectively known as the basin and range. The resulting volcanoes are completely different in character and cars to subduction zone volcanoes. That then connect to the continuation of the spreading centres a bit west. A cream material can include ocean sediment they got scraped off the top of the subducting plate. To answer that let's look at california's current plate tectonic setting. Mental maths combined with large amounts of crust on. Here along the coast that crust collides with and then sings on the northern california. Like or such centres it is offset at regular intervals by transport box. The san ...

# %%
print(summary)
# Out:
# Notice of the northern part of california we have a divergent plate boundary or an offshore seafloor spreading centre where new oceanic crust forms and then is pushed away. In this region of rifting and thin crust mantle rock is melting in rising beneath the surface just like what happens at sea for spreading divergent plate boundaries. The western continental margin of north america with a large long subduction zone with associated volcanoes and terrain accretion. This long transport boundary that connects these two sections of ocean ridge is known as the san andreas fault system. The magnitude 6.9 earthquake cause significant shaking and damage from santa cruz to san francisco as it released built up stress related to the transform plate motion. Oh the way south to the sea of cortez where connect with the seafloor spreading centres that are separating the baja peninsula from the rest of mexico. Reply with an oceanic crust leading-edge collides with the plate with continental crust on the edge. Brought out 25 million years ago the spreading centre began to be overrun. The long valley caldera is a giant crater left behind after one of the largest volcanic eruptions to happen in north america. Let's leave this unique volcanic region and return to the remnants of the ancient seduction.com volcanoes now exposes granite in the central and western series. What made it this way and why they seafloor spreading centre so close to the cotton and not in the middle of the ocean. Mammoth mountain is 1 volcanic structure found in the middle of this region known collectively as long valley. Prior to the collision of a mid-ocean ridge with a subduction zones there were hundreds of millions of years of active seduction. What happens to the seafloor spreading centre off northern california. And in california is expressed with the active volcanoes of mt lassen and mount shasta. Is the atlantic ocean spread north america was pushed westwood. How does plate tectonics affect life in california or anywhere else for that matter. During that time oceancraft was carried into the subduction zones and portions of audit carried were scraped off and attached to the edge of the can't. The most recent eruption in an area was the explosive eruption depicted in this image of mount lassen on may 22nd 1915. We can image the cross on a north america and see evidence of the old plates still seductive. And right above the start where we suspected spreading centre would now be we have an area of 10. There's still an active magma chamber under the caldera which releases carbon dioxide gases and hot water in numerous locations around the room. It has been classified as one of the largest volcanic centres in north america. Well some of the rock that makes up the santa cruz mountains in the hills of san francisco. As you can see plate tectonics has had a huge impact on a past and present landscape of california. The last eruption about 760000 years ago last bits of strewn across most of the western united states. As a result of the transfer motion sections of the southern sierra nevada granite were separated from their originations for interiors northwich. Is this map shows we have a number of plate boundaries within or near the state. If you move along the ridge north we hit this transform band. The crystal stretching has created some parallel mountains and valleys collectively known as the basin and range. The resulting volcanoes are completely different in character and cars to subduction zone volcanoes. That then connect to the continuation of the spreading centres a bit west. A cream material can include ocean sediment they got scraped off the top of the subducting plate. To answer that let's look at california's current plate tectonic setting. Mental maths combined with large amounts of crust on. Here along the coast that crust collides with and then sings on the northern california. Like or such centres it is offset at regular intervals by transport box. The san ...

# %%
len(summary)
# Out:
# 5729

# %%
# !pip install rouge
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from rouge) (1.16.0)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1

# %%
from rouge import Rouge
# Initialize ROUGE calculator
rouge = Rouge()

# Calculate ROUGE score
scores = rouge.get_scores(summary, transcript)

# Print ROUGE-1 score
print("ROUGE-1 Precision:", scores[0]["rouge-1"]["p"])
print("ROUGE-1 Recall:", scores[0]["rouge-1"]["r"])
print("ROUGE-1 F1-Score:", scores[0]["rouge-1"]["f"])
# Out:
# ROUGE-1 Precision: 1.0
# ROUGE-1 Recall: 0.8409090909090909
# ROUGE-1 F1-Score: 0.9135802419509222

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
pip install python-rake
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-rake
#   Downloading python_rake-1.5.0-py3-none-any.whl (14 kB)
# Installing collected packages: python-rake
# Successfully installed python-rake-1.5.0

# %%
pip install rake-nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rake-nltk
#   Downloading rake_nltk-1.0.6-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in /usr/local/lib/python3.9/dist-packages (from rake-nltk) (3.8.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (4.65.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (1.1.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (2022.10.31)
# Installing collected packages: rake-nltk
# Successfully installed rake-nltk-1.0.6

# %%
from rake_nltk import Rake

r = Rake()
# apply RAKE to the transcript
r.extract_keywords_from_text(transcript)

# get the top 10 keywords
keywords = r.get_ranked_phrases_with_scores()[:10]

KEYWORDS = [t[1] for t in keywords]
print(KEYWORDS)
# Out:
# ['pacific ocean look like 80 million years ago', '9 earthquake cause significant shaking', '760000 years ago last bits', 'san andreas fault system began', '25 million years ago', 'atlantic ocean spread north america', 'trench ocean sea monster island', 'past 80 million years', 'releases carbon dioxide gases', 'ground causing high rates']

# %%
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from rake_nltk import Rake
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from moviepy.editor import VideoFileClip
from datetime import timedelta

r = Rake()
# apply RAKE to the transcript
r.extract_keywords_from_text(transcript)

# get the top 10 keywords
keywords = r.get_ranked_phrases_with_scores()[:10]

KEYWORDS = [t[1] for t in keywords]
print(KEYWORDS)


# Load transcript
with open('/content/drive/MyDrive/PROJECTS/video analysis/transcript.txt', 'r') as file:
    transcript = file.read().replace('\n', '')

# Load video
video = VideoFileClip('/content/drive/MyDrive/PROJECTS/video analysis/Video.mp4')


timestamps = {}
for keyword in KEYWORDS:
    # Tokenize keyword
    keyword_tokens = word_tokenize(keyword)

    # Find time stamps
    for idx, sentence in enumerate(transcript.split('.')):
        if all(token.lower() in sentence.lower() for token in keyword_tokens):
            time_in_seconds = video.duration / len(transcript.split('.')) * idx
            timestamps[keyword] = str(timedelta(seconds=time_in_seconds))

# Convert to pandas DataFrame
df = pd.DataFrame.from_dict(timestamps, orient='index', columns=['time'])
df.index.name = 'keyword'

# Sort DataFrame by time
df = df.sort_values('time')

print(df)
# Out:
#                                                         time
# keyword
# 9 earthquake cause significant shaking        0:03:25.733043
# pacific ocean look like 80 million years ago  0:03:47.775870
# past 80 million years                         0:04:02.471087
# atlantic ocean spread north america           0:04:09.818696
# 25 million years ago                          0:04:24.513913
# san andreas fault system began                0:04:39.209130
# ground causing high rates                     0:05:45.337609
# 760000 years ago last bits                    0:07:35.551739
# releases carbon dioxide gases                 0:07:42.899348
# trench ocean sea monster island               0:10:09.851522
